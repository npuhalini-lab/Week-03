# %%
name=input("Enter the name ?")
marks=int(input("Enter the marks ?"))
if marks>80:
    Grade="A"
elif marks>=60:
    Grade="B"
elif marks>=40:
    Grade="C"
else:
    Grade="Fail"
print("Name:",name, "Marks:",marks, "Grade",Grade)
# Out:
# Enter the name ? Puhalini
# Enter the marks ? 79
# Name: Puhalini Marks: 79 Grade B
